# %% [markdown]
# # Inference RNN (GRU)
# In this python notebook, we use the validation set's last 5000 items to do inference and compute performance metrics

# %% [markdown]
# ## Pre-process validation items
# First we pre-process the last 5000 items in the validation set

# %%
# !python -m Program.preprocess --input_dir ./dataset/KQAPro.IID/ --output_dir ./processed/
# Out:
# Load questions
# Build question vocabulary
# Dump vocab to ./processed/vocab.json
# word_token_to_idx:80201
# function_token_to_idx:31
# answer_token_to_idx:80257
# Encode train set
# shape of questions, functions, func_depends, func_inputs, choices, answers:
# (94376, 85)
# (94376, 17)
# (94376, 17, 2)
# (94376, 17, 3)
# (94376, 10)
# (94376,)
# Encode val2 set
# shape of questions, functions, func_depends, func_inputs, choices, answers:
# (5000, 61)
# (5000, 16)
# (5000, 16, 2)
# (5000, 16, 3)
# (5000, 10)
# (5000,)
# Encode test set
# shape of questions, functions, func_depends, func_inputs, choices, answers:
# (11797, 51)
# (0,)
# (0,)
# (0,)
# (11797, 10)
# (0,)
# ...
# 100%|██████████| 94376/94376 [00:10<00:00, 8912.96it/s]
#
# ...
# 100%|██████████| 5000/5000 [00:00<00:00, 9588.18it/s]
#
# ...
# 100%|██████████| 11797/11797 [00:01<00:00, 10618.26it/s]

# %% [markdown]
# ## Prediction step

# %%
# !python -m Program.predict --input_dir ./processed/ --save_dir ./checkpoint
# Out:
# load kb
# load ckpt from ./checkpoint
# torch.Size([128, 61, 300])
# shape sorted.. tensor([41, 35, 30, 30, 30, 30, 28, 28, 28, 28, 26, 26, 25, 25, 24, 23, 23, 23,
#         22, 22, 22, 22, 22, 22, 22, 21, 21, 20, 20, 20, 20, 20, 20, 20, 19, 19,
#         19, 19, 19, 18, 18, 18, 18, 18, 17, 17, 17, 17, 17, 17, 17, 16, 16, 16,
#         16, 16, 16, 16, 15, 15, 15, 15, 15, 15, 15, 15, 14, 14, 14, 14, 14, 13,
#         13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 12, 12, 12, 12, 12,
#         11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 10, 10, 10, 10, 10, 10, 10,  9,
#          9,  9,  9,  9,  9,  9,  9,  9,  9,  8,  8,  8,  8,  8,  8,  7,  7,  7,
#          7,  6], device='cuda:0')
# torch.Size([128, 61, 300])
# shape sorted.. tensor([36, 35, 34, 31, 31, 28, 28, 28, 28, 27, 26, 26, 26, 26, 25, 25, 25, 25,
#         24, 23, 23, 23, 22, 22, 22, 22, 22, 22, 21, 21, 21, 21, 21, 21, 21, 21,
#         20, 20, 20, 20, 20, 20, 20, 19, 19, 19, 19, 19, 19, 19, 19, 18, 18, 18,
# ...
