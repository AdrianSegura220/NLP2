# %%
# !python -m pip install transformers
# Out:
# ...
#   Using cached transformers-4.30.2-py3-none-any.whl (7.2 MB)
# ...
#   Using cached safetensors-0.3.1-cp39-cp39-win_amd64.whl (263 kB)
# ...
#   Using cached huggingface_hub-0.15.1-py3-none-any.whl (236 kB)
# ...
#   Using cached tokenizers-0.13.3-cp39-cp39-win_amd64.whl (3.5 MB)
# ...
#
# [notice] A new release of pip available: 22.1.2 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !set CUDA_VISIBLE_DEVICES=0 & python main_nsm.py --model_name gnn --data_folder ../../webqsp/ --checkpoint_dir checkpoint/pretrain/ --batch_size 20 --test_batch_size 40 --num_step 3 --entity_dim 50 --word_dim 300 --kg_dim 100 --kge_dim 100 --eval_every 2 --encode_type --experiment_name webqsp_nsm --eps 0.95 --num_epoch 100 --use_self_loop --lr 5e-4 --word_emb_file word_emb_300d.npy --loss_type kl --reason_kb
# Out:
# building word index ...
# 2023-06-17 17:01:44,164 - root - INFO - PARAMETER----------
# 2023-06-17 17:01:44,165 - root - INFO - BATCH_SIZE=20
# 2023-06-17 17:01:44,165 - root - INFO - CHAR2ID=chars.txt
# 2023-06-17 17:01:44,165 - root - INFO - CHECKPOINT_DIR=checkpoint/pretrain/
# 2023-06-17 17:01:44,165 - root - INFO - DATA_FOLDER=../../webqsp/
# 2023-06-17 17:01:44,165 - root - INFO - DECAY_RATE=0.0
# 2023-06-17 17:01:44,165 - root - INFO - ENCODE_TYPE=True
# 2023-06-17 17:01:44,165 - root - INFO - ENCODER_TYPE=lstm
# 2023-06-17 17:01:44,165 - root - INFO - ENTITY2ID=entities.txt
# 2023-06-17 17:01:44,165 - root - INFO - ENTITY_DIM=50
# 2023-06-17 17:01:44,165 - root - INFO - ENTITY_EMB_FILE=None
# 2023-06-17 17:01:44,165 - root - INFO - ENTITY_KGE_FILE=None
# 2023-06-17 17:01:44,166 - root - INFO - ENTROPY_WEIGHT=0.0
# 2023-06-17 17:01:44,166 - root - INFO - EPS=0.95
# 2023-06-17 17:01:44,166 - root - INFO - EVAL_EVERY=2
# ...

# %%
# !set CUDA_VISIBLE_DEVICES=0 & python main_nsm.py --model_name gnn --data_folder ../../webqsp/ --checkpoint_dir webqsp_report/student/ --batch_size 20 --test_batch_size 40 --num_step 3 --entity_dim 50 --word_dim 300 --kg_dim 100 --kge_dim 100 --eval_every 2 --encode_type --experiment_name webqsp_nsm --eps 0.95 --num_epoch 100 --use_self_loop --lr 5e-4 --word_emb_file word_emb_300d.npy --loss_type kl --reason_kb --is_eval --load_experiment webqsp_t_gnn_s_gnn_fb_js-final.ckpt
# Out:
# building word index ...
# Entity: 1441420, Relation in KB: 6102, Relation in use: 6103
# loading data from ../../webqsp/test_simple.json
# skip set()
# max_facts:  21620
# converting global to local entity index ...
# avg local entity:  1447.6894447834045
# max local entity:  2000
# preparing dep ...
# preparing data ...
# 1639 cases in total, 0 cases without query entity, 1610 cases with single query entity, 29 cases with multiple query entities
# Entity: 1441420, Relation: 6103, Word: 6718
# Entity: 1441420, Relation: 6103, Word: 6718
# Load ckpt from webqsp_report/student/webqsp_t_gnn_s_gnn_fb_js-final.ckpt
# Loading pre trained model from webqsp_report/student/webqsp_t_gnn_s_gnn_fb_js-final.ckpt
# ...
